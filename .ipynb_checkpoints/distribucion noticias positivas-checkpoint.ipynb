# %%
import pandas


dataset = pandas.read_csv('data/dataset_positivas_Quellon')
dataset.drop('Unnamed: 0', axis=1, inplace=True)
dataset
# Out:
#       id_news country        media_outlet  \
# 0  21397413.0   chile           elinsular
# 1  21389031.0   chile        radioacogida
# 2  21389374.0   chile         radiopudeto
# 3  22412968.0   chile  laestrelladechiloe
#
#                                                  url  \
# 0  https://elinsular.cl/noticias/chiloe/2021/03/2...
# 1  https://radioacogida.cl/autoridades-visitan-ob...
# 2                      http://www.pudeto.cl/?p=54078
# 3  https://www.laestrellachiloe.cl/impresa/2021/0...
#
#                                                title  \
# 0     Hospital de Quellón recibe importante donación
# 1  Autoridades visitan obras concluidas de Edific...
# 2  IV Simposio Nacional de Esculturas en Castro p...
# 3   Destacan a los artesanos en su día internacional
#
#                                                 text        date title_label  \
# 0  En medio de la emergencia sanitaria provocada ...  2021-03-19         POS
# 1  Un completo recorrido por dependencias del Edi...  2021-03-30         POS
# 2  Desde el 01 al 09 de marzo se llevará a cabo e...  2021-03-04         POS
# 3  María Báez, Margarita Cáceres, Uberlinda Calbu...  2021-03-20         POS
#
#    title_score
# 0     0.978722
# 1     0.760330
# 2     0.772454
# 3     0.997125

# %%
from pandasql import sqldf

# %%
fecha9Primeros = []
fechaRestantes = []
fechasOrdenadas = []
for i in range(1, 32):
    if (i < 10):
        # fecha = fecha+str(i)
        # print(fecha)
        result = sqldf(
            "SELECT * from dataset WHERE date == '2021-03-0"+str(i)+"'  ")
        
        fecha9Primeros.append(result.shape[0])
        fechasOrdenadas.append('2021-03-0'+str(i))
    else:
        result = sqldf(
            "SELECT * from dataset WHERE date == '2021-03-"+str(i)+"'  ")
        fechaRestantes.append(result.shape[0])
        fechasOrdenadas.append('2021-03-'+str(i))

# %%
fechaPositivas = fecha9Primeros+fechaRestantes

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
plt.figure(figsize=(10, 8.5))
plt.bar(fechasOrdenadas, fechaPositivas)
plt.xlabel('Fecha')
plt.ylabel('Nro noticias positivas')
plt.xticks(rotation=90)
plt.show()
plt.savefig('DistibucionNoticiasPositivasMarzoQuellon.png')
# Out:
# <img src="data:image/png;base64,..." width="1000">
