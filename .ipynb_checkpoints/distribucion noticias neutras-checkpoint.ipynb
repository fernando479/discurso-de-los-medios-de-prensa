# %%
import pandas


dataset = pandas.read_csv('data/dataset_neutras_Quellon')
dataset.drop('Unnamed: 0', axis=1, inplace=True)
dataset
# Out:
#        id_news country        media_outlet  \
# 0   21916930.0   chile           radiosago
# 1   21917023.0   chile           radiosago
# 2   21430252.0   chile    elheraldoaustral
# 3   21475897.0   chile        elrepuertero
# 4   21467550.0   chile        elrepuertero
# ..         ...     ...                 ...
# 84  22409614.0   chile        elllanquihue
# 85  22328730.0   chile  laestrelladechiloe
# 86  22412809.0   chile  laestrelladechiloe
# 87  22412960.0   chile  laestrelladechiloe
# 88  47508207.0   chile  laestrelladechiloe
#
#                                                   url  \
# 0   https://www.radiosago.cl/salmonchile-dona-equi...
# 1   https://www.radiosago.cl/aprueban-165-millones...
# 2   https://www.eha.cl/noticia/regional/cuatro-com...
# 3   https://www.elrepuertero.cl/noticia/sociedad/q...
# 4   https://www.elrepuertero.cl/noticia/sociedad/c...
# ..                                                ...
# 84  https://www.ellanquihue.cl/impresa/2021/03/23/...
# 85  https://www.laestrellachiloe.cl/impresa/2021/0...
# 86  https://www.laestrellachiloe.cl/impresa/2021/0...
# 87  https://www.laestrellachiloe.cl/impresa/2021/0...
# 88  https://www.laestrellachiloe.cl/impresa/2021/0...
#
#                                                 title  \
# 0   Salmonchile dona equipamiento al hospital de Q...
# 1   Aprueban 165 millones para apoyar la alimentac...
# 2   Cuatro comunas cambian de Fase en el Plan Paso...
# 3   Quellón: Sobre 40 personas participaron en dos...
# 4   Conoce el Plan Paso a Paso en la Región de Los...
# ..                                                ...
# 84  Dos comunas retroceden y dos avanzan en el Pas...
# 85                                   denuncia y ayuda
# 86                                   denuncia y ayuda
# 87  Más de 56 mil isleños ya han recibido al menos...
# 88                                       MUNICIPIO DE
#
#                                                  text        date title_label  \
# 0    En medio de la emergencia sanitaria provocada...  2021-03-21         NEU
# 1   Se trata del proyecto “Entrega de servicios de...  2021-03-19         NEU
# 2   El seremi de Salud, Alejandro Caroca, anunció ...  2021-03-23         NEU
# 3   Este domingo y en pleno horario de toque de qu...  2021-03-21         NEU
# 4    Dado a la crisis sanitaria y el aumento de ca...  2021-03-25         NEU
# ..                                                ...         ...         ...
# 84  Una serie de cambios y nuevas medidas de endur...  2021-03-23         NEU
# 85  recintos de vacunación cierran por restricción...  2021-03-28         NEU
# 86  avanza proyecto habitacional en chonchi.- En s...  2021-03-12         NEU
# 87  Mientras al cierre Chile llevaba 5.475.578 de ...  2021-03-20         NEU
# 88  Muchos años debieron pasar, en los cuales se r...  2021-03-12         NEU
#
#     title_score
# 0      0.997347
# 1      0.995629
# 2      0.995627
# 3      0.981127
# 4      0.995957
# ..          ...
# 84     0.953248
# 85     0.996011
# 86     0.996011
# 87     0.995668
# 88     0.789915
#
# [89 rows x 9 columns]

# %%
from pandasql import sqldf

# %%
fecha9Primeros = []
fechaRestantes = []
fechasOrdenadas = []
for i in range(1, 32):
    if (i < 10):
        # fecha = fecha+str(i)
        # print(fecha)
        result = sqldf(
            "SELECT * from dataset WHERE date == '2021-03-0"+str(i)+"'  ")
        
        fecha9Primeros.append(result.shape[0])
        fechasOrdenadas.append('2021-03-0'+str(i))
    else:
        result = sqldf(
            "SELECT * from dataset WHERE date == '2021-03-"+str(i)+"'  ")
        fechaRestantes.append(result.shape[0])
        fechasOrdenadas.append('2021-03-'+str(i))

# %%
fechaNegativas = fecha9Primeros+fechaRestantes

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
plt.figure(figsize=(10, 8.5))
plt.bar(fechasOrdenadas, fechaNegativas)
plt.xlabel('Fecha')
plt.ylabel('Nro noticias neutras')
plt.xticks(rotation=90)
plt.show()
plt.savefig('DistibucionNoticiasNeutrasMarzoQuellon.png')
# Out:
# <img src="data:image/png;base64,..." width="1000">
